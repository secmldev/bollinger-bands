# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import date

from mod_my_utils.read_write_data import *
from mod_bb_utils.bb import *

# %%
symbols = ["HDFC", 'RELIANCE', 'TCS', 'HINDUNILVR', 'INFY', 'HDFC', 'BHARTIARTL', 'ITC', 'ASIANPAINT', 'NESTLEIND', 'HCLTECH', 'SBI', 'SBIN']

# %%
symbol = symbols[0]
data_source = "yahoo"
# MM/DD/YYYY
start_date = "1/1/2010"
end_date = "1/1/2015"
print(start_date)
print(end_date)
print(symbol)
# Out:
# 1/1/2010
# 1/1/2015
# HDFC

# %%
stock_data = get_price_yahoo(symbol=symbol, data_source=data_source, start_date= start_date, end_date= end_date )
# Out:
# stock name HDFC

# %%
data = stock_data[["Adj Close"]].copy()
data.columns = ["price"]
data.head(5)
# Out:
#                  price
# Date
# 2010-01-04  442.267822
# 2010-01-05  443.772766
# 2010-01-06  445.905975
# 2010-01-07  437.604187
# 2010-01-08  429.980530

# %%
bb = get_bb_values(data)

# %%
bb.head()
# Out:
#                  price  middleband  upperband  lowerband
# Date
# 2010-01-04  442.267822         NaN        NaN        NaN
# 2010-01-05  443.772766         NaN        NaN        NaN
# 2010-01-06  445.905975         NaN        NaN        NaN
# 2010-01-07  437.604187         NaN        NaN        NaN
# 2010-01-08  429.980530         NaN        NaN        NaN

# %%
signals = get_bb_signal(bb)

# %%
signals.head()
# Out:
#                  price  buy_sell
# Date
# 2010-01-04  442.267822       NaN
# 2010-01-05  443.772766       0.0
# 2010-01-06  445.905975       0.0
# 2010-01-07  437.604187       0.0
# 2010-01-08  429.980530       0.0

# %%
plot_bb_buy_sell(bb, signals)
